# %%
#Simple assignment
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By

options = Options()
options.headless = True
options.add_argument("--enable-javascript")
options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36")

with webdriver.Chrome(ChromeDriverManager().install(), options=options) as driver:
   while True:
      try:
         print(1)
         driver.get("https://courses.students.ubc.ca/cs/courseschedule?pname=subjarea&tname=subj-section&dept=FNH&course=413&section=001")
         assert driver.find_element(By.CSS_SELECTOR, "tr:nth-child(2) strong").text == "45"
      except AssertionError: 
         break
   print(driver.find_element(By.CSS_SELECTOR, "tr:nth-child(2) strong").text)
   print(driver.page_source)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/Users/wilsontu/.wdm/drivers/chromedriver/mac64/91.0.4472.101/chromedriver] found in cache
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-1bba8ad7cb70> in <module>
#      13    while True:
#      14       try:
# ---> 15          driver.get("https://courses.students.ubc.ca/cs/courseschedule?pname=subjarea&tname=subj-section&dept=FNH&course=413&section=001")
#      16          assert driver.find_element(By.CSS_SELECTOR, "tr:nth-child(2) strong").text == "45"
#      17       except AssertionError:
#
# /opt/homebrew/anaconda3/envs/DataManipulation/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# ...
